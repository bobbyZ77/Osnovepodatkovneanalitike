# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbyZ77/Osnovepodatkovneanalitike/blob/main/osnove_podatkovne_analitike_1_del.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.6.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.23
# albumentations                        2.0.5
# ale-py                                0.10.2
# altair                                5.5.0
# annotated-types                       0.7.0
# anyio                                 4.9.0
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.1
# arviz                                 0.21.0
# astropy                               7.0.1
# astropy-iers-data                     0.2025.4.21.0.37.6
# ...

# %% [markdown]
# # Uvod
#
# ## Uvoz modulov

# %%
import pandas as pd
import random as rd
import math as mt

# %%
rd.randint(10,100)
# Out:
# 31

# %%
# create a list of 100 random numbers between 1 and 1000
random_number=[]
for stevec in range (100):
  print ("Korak " + str(stevec + 1))
  vrednost=rd.randint(1,1000)
  print(vrednost)
  random_number.append(vrednost)

random_number[:10]
# Out:
# Korak 1
# 729
# Korak 2
# 311
# Korak 3
# 28
# Korak 4
# 663
# Korak 5
# 13
# Korak 6
# 867
# Korak 7
# 693
# Korak 8
# 309
# Korak 9
# 67
# Korak 10
# 441
# Korak 11
# 26
# Korak 12
# 230
# Korak 13
# 879
# Korak 14
# 514
# Korak 15
# 152
# Korak 16
# 818
# Korak 17
# 627
# Korak 18
# 302
# Korak 19
# 406
# Korak 20
# 162
# Korak 21
# 461
# Korak 22
# 319
# Korak 23
# 374
# Korak 24
# 814
# Korak 25
# 778
# Korak 26
# 394
# Korak 27
# 777
# Korak 28
# 93
# Korak 29
# 697
# Korak 30
# 710
# Korak 31
# 562
# Korak 32
# 45
# Korak 33
# 88
# Korak 34
# 882
# Korak 35
# 890
# Korak 36
# 571
# Korak 37
# 61
# Korak 38
# 947
# Korak 39
# 59
# Korak 40
# 718
# Korak 41
# 866
# Korak 42
# 798
# Korak 43
# 816
# Korak 44
# 228
# Korak 45
# 113
# Korak 46
# 877
# Korak 47
# 697
# Korak 48
# 352
# Korak 49
# 18
# Korak 50
# 819
# Korak 51
# 131
# Korak 52
# 547
# Korak 53
# 306
# Korak 54
# 332
# Korak 55
# 310
# Korak 56
# 665
# Korak 57
# 837
# Korak 58
# 44
# Korak 59
# 920
# Korak 60
# 501
# ...

# %%
vrednost=200
# print(f"Na predstavi se je zbralo" + str (vrednost)+" ljudi.")
print (f"Na predstavi se je zbralo (vrednost) ljudi"")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ee21e3baedb7> in <cell line: 0>()
# ----> 1 random_numbers
#
# NameError: name 'random_numbers' is not defined
